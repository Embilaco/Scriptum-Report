# %% [markdown]
# # Check a YAML report by hand
#
# Runs `powerpoint_input.yaml` through the loader and the docx back end, and shows what
# comes out at every stage: the tasks, the finished document, and how it compares
# with the reference captured from the old `.rdf`.

# %%
import subprocess
import sys
from pathlib import Path

import Scriptum
import yaml

# Derived from where this notebook sits, so moving the worktree does not
# turn the check below into a false alarm. Jupyter starts in the notebook's
# own directory, and this cell runs before anything changes it.
NOTEBOOK_DIR = Path.cwd()
WORKTREE = NOTEBOOK_DIR.parents[2]
here = Path(Scriptum.__file__).resolve().parent.parent

print('python    ', sys.executable)
print('Scriptum  ', Path(Scriptum.__file__).resolve())
print('PyYAML    ', yaml.__version__)
print('branch    ', subprocess.run(['git', 'branch', '--show-current'], cwd=here,
                                   capture_output=True, text=True).stdout.strip())

if here != WORKTREE:
    print()
    print('WARNING: Scriptum is NOT coming from the dev-yaml worktree.')
    print('         Expected', WORKTREE)
    print('         Pick the .venv313 kernel of that worktree - see the cell above.')
else:
    print()
    print('OK: importing from the dev-yaml worktree.')
# Out:
# python     e:\users\tel\Python\dev\Scriptum-Report-dev-yaml\.venv313\Scripts\python.exe
# Scriptum   E:\users\tel\Python\dev\Scriptum-Report-dev-yaml\Scriptum\__init__.py
# PyYAML     6.0.3
# branch     dev-yaml
#
# OK: importing from the dev-yaml worktree.

# %% [markdown]
# ## A workspace
#
# The run writes a document and needs its data beside it, so everything is copied
# to a temp directory. The repo stays clean, and you can throw the directory away.

# %%
import os
import shutil
import tempfile

REPORT_DIR = WORKTREE / 'tests' / '04_examples' / 'pptreport'
DATA_SOURCE = WORKTREE / 'tests' / 'data_source'

def workspace():
    """A fresh directory holding the fixtures, the template and the data."""
    work = Path(tempfile.mkdtemp(prefix='scriptum-'))
    for pattern in ('*.yaml', 'template.pptx'):
        for path in REPORT_DIR.glob(pattern):
            shutil.copy(path, work)
    shutil.copytree(DATA_SOURCE, work / 'data', dirs_exist_ok=True)
    os.chdir(work)
    return work

WORK = workspace()
print('working in', WORK)
print(sorted(p.name for p in WORK.iterdir()))
# Out:
# working in C:\Users\tel\AppData\Local\Temp\scriptum-6yrk25hx
# ['data', 'powerpoint_input.yaml', 'template.pptx']

# %% [markdown]
# ## 1. Read the document
#
# `ReportDataFile` reads a `.yaml` document through `Scriptum.rdf.loader`;
# anything else is refused with a message. The `.rdf` text parser is gone.
#
# A broken document raises `DocumentError` carrying **every** diagnostic, not the
# first — there is a cell near the bottom that shows one.

# %%
rdf = Scriptum.ReportDataFile('powerpoint_input.yaml')

print('documenttype:', rdf.settings.documenttype)
print('datadir     :', rdf.settings.datadir)
print('tasks       :', len(rdf.tasks))
print('errors      :', rdf.errors or 'none')
# Out:
# documenttype: pptx
# datadir     : data
# tasks       : 69
# errors      : none

# %% [markdown]
# ## 2. What the tasks say
#
# `what` is the operation, `where` the marker an *add* lands at, `target` the
# **template name** — the tag written in the .docx — and the address the
# **instance**: `subsection:instruction::2` is the second copy of that block.
#
# Note the `_global_` tasks at the end: global fills are applied last, and the
# task list carries that rule so no back end has to remember it.

# %%
def show_tasks(tasks, limit=None, only=None):
    rows = [t for t in tasks if only is None or only in '.'.join(t.myAddress)]
    print(f'{"#":>4}  {"what":6} {"where":18} {"target":22} address')
    print('-' * 110)
    for t in rows[:limit]:
        print(f'{t.serial:>4}  {t.what or "-":6} {t.where or "-":18} '
              f'{t.target or "-":22} {".".join(t.myAddress)}')
    if limit and len(rows) > limit:
        print(f'... {len(rows) - limit} more')

show_tasks(rdf.tasks, limit=40)
# Out:
#    #  what   where              target                 address
# --------------------------------------------------------------------------------------------------------------
#    1  copy   -                  -                      :titleslide::1
#    2  -      -                  title                  :titleslide::1.:title::1
#    3  -      -                  subtitle               :titleslide::1.:subtitle::1
#    4  -      -                  image:main_model       :titleslide::1.image:main_model::1
#    5  copy   -                  -                      :taskprojectdefinition::1
#    6  -      -                  image:model_icon       :taskprojectdefinition::1.image:model_icon::1
#    7  -      -                  manu                   :taskprojectdefinition::1.:manu::1
#    8  -      -                  plat                   :taskprojectdefinition::1.:plat::1
#    9  -      -                  hierarchy              :taskprojectdefinition::1.:hierarchy::1
#   10  -      -                  proj_ver               :taskprojectdefinition::1.:proj_ver::1
#   11  -      -                  prod_ver               :taskprojectdefinition::1.:prod_ver::1
#   12  -      -                  group                  :taskprojectdefinition::1.:group::1
#   13  -      -                  manager                :taskprojectdefinition::1.:manager::1
#   14  -      -                  proj_no                :taskprojectdefinition::1.:proj_no::1
#   15  -      -                  glob_no                :taskprojectdefinition::1.:glob_no::1
#   16  -      -                  sop                    :taskprojectdefinition::1.:sop::1
#   17  -      -                  mod_ver                :taskprojectdefinition::1.:mod_ver::1
#   18  -      -                  items                  :taskprojectdefinition::1.:items::1
#   19  -      -                  belongs                :taskprojectdefinition::1.:belongs::1
#   20  -      -                  plant                  :taskprojectdefinition::1.:plant::1
#   21  -      -                  report_no              :taskprojectdefinition::1.:report_no::1
#   22  -      -                  name:surname1          :taskprojectdefinition::1.name:surname1::1
#   23  -      -                  name:surname2          :taskprojectdefinition::1.name:surname2::1
#   24  -      -                  name:surname3          :taskprojectdefinition::1.name:surname3::1
#   25  -      -                  name:surname4          :taskprojectdefinition::1.name:surname4::1
#   26  -      -                  name:surname5          :taskprojectdefinition::1.name:surname5::1
#   27  -      -                  dep:phone1             :taskprojectdefinition::1.dep:phone1::1
#   28  -      -                  dep:phone2             :taskprojectdefinition::1.dep:phone2::1
#   29  -      -                  dep:phone3             :taskprojectdefinition::1.dep:phone3::1
#   30  -      -                  dep:phone4             :taskprojectdefinition::1.dep:phone4::1
#   31  -      -                  dep:phone5             :taskprojectdefinition::1.dep:phone5::1
#   32  -      -                  rf1                    :taskprojectdefinition::1.:rf1::1
#   33  -      -                  rf2                    :taskprojectdefinition::1.:rf2::1
#   34  add    marker:content::1  p:heading              :taskprojectdefinition::1.p:heading::1
#   35  copy   -                  -                      :material::1
#   36  -      -                  title                  :material::1.:title::1
#   37  -      -                  plant                  :material::1.:plant::1
#   38  add    marker:content::1  p:default              :material::1.p:default::1
#   39  add    marker:table::1    table:blue             :material::1.table:blue::1
#   40  copy   -                  -                      :resultsgeneral::1
# ... 29 more

# %% [markdown]
# Try `show_tasks(rdf.tasks, only='subsection:instruction')` to see just the
# repeated block — instance 1 **applies** to what the template already holds, and
# 2 and 3 are **copies**.

# %%
show_tasks(rdf.tasks, only=':taskprojectdefinition')
# Out:
#    #  what   where              target                 address
# --------------------------------------------------------------------------------------------------------------
#    5  copy   -                  -                      :taskprojectdefinition::1
#    6  -      -                  image:model_icon       :taskprojectdefinition::1.image:model_icon::1
#    7  -      -                  manu                   :taskprojectdefinition::1.:manu::1
#    8  -      -                  plat                   :taskprojectdefinition::1.:plat::1
#    9  -      -                  hierarchy              :taskprojectdefinition::1.:hierarchy::1
#   10  -      -                  proj_ver               :taskprojectdefinition::1.:proj_ver::1
#   11  -      -                  prod_ver               :taskprojectdefinition::1.:prod_ver::1
#   12  -      -                  group                  :taskprojectdefinition::1.:group::1
#   13  -      -                  manager                :taskprojectdefinition::1.:manager::1
#   14  -      -                  proj_no                :taskprojectdefinition::1.:proj_no::1
#   15  -      -                  glob_no                :taskprojectdefinition::1.:glob_no::1
#   16  -      -                  sop                    :taskprojectdefinition::1.:sop::1
#   17  -      -                  mod_ver                :taskprojectdefinition::1.:mod_ver::1
#   18  -      -                  items                  :taskprojectdefinition::1.:items::1
#   19  -      -                  belongs                :taskprojectdefinition::1.:belongs::1
#   20  -      -                  plant                  :taskprojectdefinition::1.:plant::1
#   21  -      -                  report_no              :taskprojectdefinition::1.:report_no::1
#   22  -      -                  name:surname1          :taskprojectdefinition::1.name:surname1::1
#   23  -      -                  name:surname2          :taskprojectdefinition::1.name:surname2::1
#   24  -      -                  name:surname3          :taskprojectdefinition::1.name:surname3::1
#   25  -      -                  name:surname4          :taskprojectdefinition::1.name:surname4::1
#   26  -      -                  name:surname5          :taskprojectdefinition::1.name:surname5::1
#   27  -      -                  dep:phone1             :taskprojectdefinition::1.dep:phone1::1
#   28  -      -                  dep:phone2             :taskprojectdefinition::1.dep:phone2::1
#   29  -      -                  dep:phone3             :taskprojectdefinition::1.dep:phone3::1
#   30  -      -                  dep:phone4             :taskprojectdefinition::1.dep:phone4::1
#   31  -      -                  dep:phone5             :taskprojectdefinition::1.dep:phone5::1
#   32  -      -                  rf1                    :taskprojectdefinition::1.:rf1::1
#   33  -      -                  rf2                    :taskprojectdefinition::1.:rf2::1
#   34  add    marker:content::1  p:heading              :taskprojectdefinition::1.p:heading::1

# %% [markdown]
# ## 3. Build the document
#
# Anything the back end could not place prints a `WARNING`. A clean run prints
# none.

# %%
import contextlib
import io as _io

with contextlib.redirect_stdout(_io.StringIO()) as printed:
    managed = Scriptum.ManagedPptx('template.pptx', rdf)
    managed.artist(rdf)
    managed.save('report.pptx',finish=True)

complaints = [line for line in printed.getvalue().splitlines()
              if 'WARNING' in line or 'ERROR' in line]
print('written:', WORK / 'report.pptx')
print('complaints:', len(complaints))
for line in complaints[:20]:
    print('  ', line)
# Out:
# written: C:\Users\tel\AppData\Local\Temp\scriptum-6yrk25hx\report.pptx
# complaints: 0

# %% [markdown]
# ## 4. Read it back
#
# Open `report.docx` in Word if you want to look at the formatting; this shows
# what it *says*, which is what the automated comparison uses.

# %%
import pptx

def spoken(path):
    document = pptx.Presentation(path)
    said = [p.text.strip() for p in document.paragraphs]
    for table in document.tables:
        for row in table.rows:
            said.extend(cell.text.strip() for cell in row.cells)
    return [line for line in said if line]

lines = spoken(WORK / 'report.pptx')
print(len(lines), 'non-empty lines')
for line in lines[:30]:
    print('  ', line[:100])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       7         for row in table.rows:
#       8             said.extend(cell.text.strip() for cell in row.cells)
#       9     return [line for line in said if line]
#      10
# ---> 11 lines = spoken(WORK / 'report.pptx')
#      12 print(len(lines), 'non-empty lines')
#      13 for line in lines[:30]:
#      14     print('  ', line[:100])
#
# Cell In[10], line 5, in spoken(path)
#       3 def spoken(path):
#       4     document = pptx.Presentation(path)
# ----> 5     said = [p.text.strip() for p in document.paragraphs]
#       6     for table in document.tables:
#       7         for row in table.rows:
#       8             said.extend(cell.text.strip() for cell in row.cells)
#
# AttributeError: 'Presentation' object has no attribute 'paragraphs'

# %% [markdown]
# ## 5. Compare with the reference
#
# `expected/powerpoint_input.json`, beside this notebook, is what this
# fixture's **`.rdf`** produced before the back end changed (the `.rdf` and its
# parser are gone; the reference is their record). Digits and weekday
# names are collapsed on both sides, because the reference was captured on
# another day and `date:now` is evaluated per run.
#
# An empty report below means the YAML document says exactly what the text one
# said.

# %%
import json
import re

DIGITS = re.compile(r'\d+')
WEEKDAY = re.compile(r'\b(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun)\b')

def normalise(lines):
    return [WEEKDAY.sub('#', DIGITS.sub('#', line)) for line in lines]

REFERENCE = REPORT_DIR / 'expected' / 'powerpoint_input.json'

expected = normalise(json.loads(REFERENCE.read_text(encoding='utf-8')))
got = normalise(spoken(WORK / 'report.pptx'))

print(f'reference {len(expected)} lines, this run {len(got)} lines')
if expected == got:
    print('IDENTICAL')
else:
    for i, (a, b) in enumerate(zip(expected, got)):
        if a != b:
            print(f'first difference at line {i}')
            print('  reference:', a[:110])
            print('  this run :', b[:110])
            break
    else:
        print('one is a prefix of the other')
# Out:
# reference 213 lines, this run 213 lines
# IDENTICAL

# %% [raw]
# for i,line in enumerate(expected):
#     print(i,line,got[i])
